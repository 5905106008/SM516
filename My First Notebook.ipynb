# %% [markdown]
# # <center> SM516 การโปรแกรมขั้นสูง

# %% [markdown]
# <img src ="image/snsd1.png" width=250 align="right">

# %% [markdown]
# <div align="right"> มณีจันท์ จันทร์จารุพงศ์<br>วิศวกรรมการเงิน<br> 11 มกราคม 2563 </div>

# %%
from IPython.lib.display import YouTubeVideo 
YouTubeVideo('6pA_Tou-DPI')

# %% [markdown]
# ## การวัดผล
#
# 1. กิจกรรมในห้องเรียน 40%
#     * สมุดจด 30%
#     * การโปรแกรม 10%
# * การบ้าน 20% $\rightarrow$ จัดเก็บลงบน **flashdrive** ส่งในวันสอบปลายภาค
# * สอบปลายภาค 60% (ได้คะแนนน้อยกว่า 15% ให้เรียนใหม่)

# %% [markdown]
# ## การติดตั้งโปรแกรม
#
# 1. [Winpython](https://winpython.github.io/)
# ![](https://winpython.github.io/images/winpython_title.png)

# %% [markdown]
# ## เนื้อหา
# * Python
#     - Installation
#     - Jupyter notebook
#         - Markdown
#             - Markdown
#             - Html
#             - LaTex
#     - Object Oriented Programmimg (OOP)
#         - Object
#             - Single Object
#             - Container
#         - Expression
#             - Operators
#             - Logic
#         - commmands
#             - Conditions
#             - Repetition
#         - Module
#             - Packages
#                 - math and cmath
#                 - numpy
#                 - matplotlib
#                 - pandas
#                 - sympy
#         - Program
#             - Jupyter notebook/ Jupyter Lab
#             - vscode
#             - pyCharm
# * Repository and Code Version Control (GitHub)
# * Python for Finance
# * Python for Statistics
#
# * R Programming

# %% [markdown]
# ## เอกสารอ้างอิง
#
# * หนังสือหลักสำหรับ Python คือ Mark Lutz [Learning Python 5th Edition](https://www.amazon.com/Learning-Python-5th-Mark-Lutz/dp/1449355730)
#     - [Local copy]

# %% [markdown]
# $\alpha$ dsadsadsd
# $$ ax^2 +bs +c =0 \tag{1}$$

# %% [markdown]
# $$x = \frac{-b \pm \sqrt{b^2 -4ac}}{2a} \tag{2}$$

# %% [markdown]
# $$
# \left[
# \begin{array}{rrr}
# -1 & 0 & 1 \\
# -2 & -3 & 4 \\
# 3 & 12 & 256 \\
# \end{array}
# \right]
# \left[
# \begin{array}{c}
# x \\ y \\ z
# \end{array}
# \right]
# =
# \left[
# \begin{array}{1}
# 8 \\ 7 \\ 12
# \end{array}
# \right]
# \tag{3}
# $$

# %% [markdown]
# <u>เอกสาร<u>
